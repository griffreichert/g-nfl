# %%
import jupyter_black

jupyter_black.load()

import pandas as pd
from nfl.utils.connections import load_service_account

sa = load_service_account()

# %%
sheet = sa.open("NFL Power Ratings - 2023")

# %%
sheet
# Out:
# <Spreadsheet 'NFL Power Ratings - 2023' id:1UztqNjYoXDeBsNoHFo3lPPIvqtZEu4RWqLkyUAaNZp8>

# %%
work_sheet = sheet.worksheet("Wk 14")

df = pd.DataFrame(work_sheet.get_all_records())

# %%
df
# Out:
#    team  ovr  off  def                                          off_notes  \
# 0    SF  7.6  4.7  2.9        deebo game, offense is a truck when healthy
# 1   BAL  5.5  2.5  3.0                                                bye
# 2   MIA  5.5  5.3  0.2  properly rated, tyreek opoy, achane back and p...
# 3   DAL  5.1  2.6  2.5        mccarthy bad playcalling, dak still dealing
# 4   PHI  5.0  4.4  0.6  out physicalled but coming off short rest, won...
# 5    KC  4.8  2.9  1.9                                    big rashee game
# 6   BUF  3.6  3.4  0.2                                                bye
# 7   JAX  2.8  2.4  0.4
# 8   HOU  1.8  2.0 -0.2  running game not that great, stroud is money, ...
# 9   DET  1.7  3.1 -1.4       running game is impressive, decent goff game
# 10   GB  0.2 -0.2  0.4                Love pt 2!! christian watson injury
# 11   LA -0.5  0.2 -0.7  Stafford looked great against the blitz, monit...
# 12  DEN -0.5 -0.3 -0.2  big questions about the offense still, picks c...
# 13  LAC -0.5  1.6 -2.1  6 points against the pats is garbage, keenan b...
# 14  IND -0.9 -0.1 -0.8  gardner is a walking turnover, JT on IR, Steik...
# 15  MIN -1.1 -1.2  0.1                                                bye
# 16  CHI -1.2 -1.7  0.5                                                bye
# 17  CLE -1.4 -2.2  0.8                                flacco looked good!
# 18  PIT -1.5 -2.4  0.9  pickett done for season, tomlin uninspiring pl...
# 19   NO -1.6 -0.7 -0.9              derek carr murdered, kamara has juice
# 20  SEA -1.7 -0.2 -1.5                               geno looking healthy
# 21  ATL -1.8 -1.5 -0.3  ridder throwing downfield is not a recipe for ...
# 22  ARI -2.7  0.1 -2.8                    Kyler game, mcbride is a weapon
# 23  TEN -3.0 -2.4 -0.6  derrick henry looked great then got hurt, levi...
# 24  CIN -3.0 -1.9 -1.1
# 25   TB -3.6 -1.8 -1.8        evans looks banged up, still plays well tho
# 26  WAS -3.7 -1.4 -2.3    howell avoided sacks but bad pick 6 and 4.1 ypa
# 27   LV -3.9 -2.3 -1.6                                                bye
# 28  NYJ -4.0 -6.5  2.5                                               yuck
# 29  CAR -6.0 -3.6 -2.4            really hard to consider bryce an nfl qb
# 30   NE -6.2 -5.0 -1.2                    benched zappe, scored no points
# 31  NYG -6.9 -6.1 -0.8                                                bye
#
#                                             def_notes
# 0   pressured hurts a lot, plays so physical, gree...
# 1                                                 bye
# 2
# 3              secondary got burned by good receivers
# 4                                       bad secondary
# 5                               did not show up in GB
# 6                                                 bye
# 7   could you please not let Jake Browning score 3...
# 8        stingley was impressive, pass rush was solid
# 9                    nothing inspiring, very gettable
# 10                                           pressure
# 11
# 12                                  surtain banged up
# 13                                      bottom 5 unit
# 14     defensive special teams luck (2 blocked punts)
# 15                                                bye
# 16                                                bye
# 17        defense did nothing, different without ward
# 18                                       watt injured
# 19  defense is a joke, not playoff calibre without...
# 20                                 defense is baaaaad
# 21
# 22  bad weather, pickett out, not giving them a to...
# 23                 pass funnel, justin simmons injury
# 24
# 25                                           injuries
# 26  unserious playcalling, cant let tyreek beat yo...
# 27                                                bye
# 28                                       fairly rated
# 29                            defense came back a bit
# 30                                                  ?
# 31                                                bye

# %%
# sheet.add_worksheet("gr-test", rows=1000, cols=1000)
