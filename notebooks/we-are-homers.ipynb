# %%
import sys
import os
# Navigate up one level to the parent directory and append it to sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))
import nfl_data_py as nfl
import pandas as pd
from src import utils

# %% [markdown]
# ## Questions to answer
# * Who was the best picker over the period of time?
# * What trends emerged (picking home/away, dogs/favorites)
# * Were we homers? (picking our teams, picking the same teams)
# * Was there correlation between doing well one week, and doing well the next week?
# * Did the different lines matter?

# %%
teams = utils.get_nfl_teams()

# %%
def parse_picks(season, week):
    df = pd.read_excel(f'../../data/betting/homers-{season}.xlsx', sheet_name=f'Wk {week}', usecols=range(14), header=1)
    df = df.drop(df.index[9:])
    df = df.dropna(axis=1, how='all')
    if 'Notes' in df.columns:
        df = df.drop(columns=['Notes'])
    df = df.drop(columns=[col for col in df.columns if 'Unnamed' in col])
    df = utils.clean_df_columns(df)
    df = df.rename(columns={'team': 'final', 'picks': 'pick_type'})
    assert all(col in ['pick_type', 'final', 'ben', 'chuck', 'griffin', 'harry', 'hunter'] for col in df.columns)
    assert len(df) == 9
    df['pick_type'] = df.pick_type.map({i: 'reg' for i in range(1, 6)}).fillna(df['pick_type']).apply(str.lower)
    df['pick_type'] = df.pick_type.map({'underdog': 'ud', 'survivor': 'sd'}).fillna(df['pick_type'])
    df['pick_type'] = df.pick_type.apply(lambda x: 'reg' if x not in ['bb', 'reg', 'sd', 'ud', 'mnf'] else x)

    transformed = pd.melt(df, id_vars=['pick_type'], var_name='picker', value_name='pick').dropna()
    transformed['season'] = season
    transformed['week'] = week
    transformed['pick'] = transformed['pick'].apply(str.upper).apply(str.strip).apply(lambda x: x.split('/')[0] if '/' in x else x)
    transformed = transformed[transformed['pick'] != '']
    # Map bad team names
    transformed['pick'] = transformed['pick'].map({
        'LAR': 'LA', 
        'WSH': 'WAS', 
        'WFT': 'WAS',
        'JAG': 'JAX',
        'JAC': 'JAX',
        'PHL': 'PHI',
    }).fillna(transformed['pick'])

    bad_teams = [team for team in transformed['pick'].unique() if team not in teams]
    assert len(bad_teams) == 0, bad_teams

    joined = pd.merge(transformed, nfl.import_schedules([season])[['game_id', 'season', 'week', 'away_team', 'home_team', 'away_score', 'home_score', 'result', 'spread_line']], on=['season', 'week'])

    reduced = joined[(joined['pick'] == joined['away_team']) | (joined['pick'] == joined['home_team'])]
    del joined
    assert len(reduced) == len(transformed)


    reduced['away_cover'] = reduced.apply(utils.cover_result, axis=1)
    reduced['home_cover'] = 1 - reduced['away_cover']

    reduced['pick_result'] = reduced.apply(utils.pick_result, axis=1)
    print(season, week, reduced.shape[0])
    return reduced

# %%
homers = pd.concat([parse_picks(szn, wk) for szn in [2022] for wk in range(1, 19)], ignore_index=True)
homers.shape
# Out:
# 2022 1 54
# 2022 2 54
# 2022 3 54
# 2022 4 54
# 2022 5 54
# 2022 6 54
# 2022 7 48
# 2022 8 48
# 2022 9 45
# 2022 10 48
# 2022 11 48
# 2022 12 48
# 2022 13 48
# 2022 14 48
# 2022 15 48
# 2022 16 48
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 homers = pd.concat([parse_picks(szn, wk) for szn in [2022] for wk in range(1, 19)], ignore_index=True)
#       2 homers.shape
#
# Cell In[38], line 1, in <listcomp>(.0)
# ----> 1 homers = pd.concat([parse_picks(szn, wk) for szn in [2022] for wk in range(1, 19)], ignore_index=True)
#       2 homers.shape
#
# Cell In[37], line 38, in parse_picks(season, week)
#      36 reduced = joined[(joined['pick'] == joined['away_team']) | (joined['pick'] == joined['home_team'])]
#      37 del joined
# ---> 38 assert len(reduced) == len(transformed)
#      41 reduced['away_cover'] = reduced.apply(utils.cover_result, axis=1)
#      42 reduced['home_cover'] = 1 - reduced['away_cover']
#
# AssertionError:

# %%
week = 17
season = 2022

# %%
df = pd.read_excel(f'../../data/betting/homers-{season}.xlsx', sheet_name=f'Wk {week}', usecols=range(14), header=1)
df = df.drop(df.index[9:])
df = df.dropna(axis=1, how='all')
if 'Notes' in df.columns:
    df = df.drop(columns=['Notes'])
df = df.drop(columns=[col for col in df.columns if 'Unnamed' in col])
df = utils.clean_df_columns(df)
df = df.rename(columns={'team': 'final', 'picks': 'pick_type'})
assert all(col in ['pick_type', 'final', 'ben', 'chuck', 'griffin', 'harry', 'hunter'] for col in df.columns)
assert len(df) == 9
df['pick_type'] = df.pick_type.map({i: 'reg' for i in range(1, 6)}).fillna(df['pick_type']).apply(str.lower)
df['pick_type'] = df.pick_type.map({'underdog': 'ud', 'survivor': 'sd'}).fillna(df['pick_type'])
df['pick_type'] = df.pick_type.apply(lambda x: 'reg' if x not in ['bb', 'reg', 'sd', 'ud', 'mnf'] else x)
df
# Out:
#   pick_type final  ben chuck griffin harry hunter
# 0        bb   JAX  LAC   MIN     JAX   MIN    NYG
# 1       reg   PIT   KC   NYJ      NE    SF    JAX
# 2       reg   MIN   NE   PHI     BAL   NYJ    NYJ
# 3       reg   NYJ  CAR   JAX     LAR   MIA    PIT
# 4       reg   NYG  CLE   DEN     ARI   CAR    CLE
# 5       reg    SF  IND   CAR     WAS   ATL    CIN
# 6        ud   ARI  ARI   DEN     ARI   DEN     LV
# 7        sd   NaN  NaN   NaN     NaN   NaN    NaN
# 8       mnf   CIN  BUF   CIN     BUF   CIN    CIN

# %%
transformed = pd.melt(df, id_vars=['pick_type'], var_name='picker', value_name='pick').dropna()
transformed['season'] = season
transformed['week'] = week
transformed = transformed[transformed['pick'] != '']
# Map bad team names
transformed['pick'] = transformed['pick'].map({
    'LAR': 'LA', 
    'WSH': 'WAS', 
    'WFT': 'WAS',
    'JAG': 'JAX',
    'JAC': 'JAX',
    'PHL': 'PHI',
}).fillna(transformed['pick'])
transformed
# Out:
#    pick_type   picker pick  season  week
# 0         bb    final  JAX    2022    17
# 1        reg    final  PIT    2022    17
# 2        reg    final  MIN    2022    17
# 3        reg    final  NYJ    2022    17
# 4        reg    final  NYG    2022    17
# 5        reg    final   SF    2022    17
# 6         ud    final  ARI    2022    17
# 8        mnf    final  CIN    2022    17
# 9         bb      ben  LAC    2022    17
# 10       reg      ben   KC    2022    17
# 11       reg      ben   NE    2022    17
# 12       reg      ben  CAR    2022    17
# 13       reg      ben  CLE    2022    17
# 14       reg      ben  IND    2022    17
# 15        ud      ben  ARI    2022    17
# 17       mnf      ben  BUF    2022    17
# 18        bb    chuck  MIN    2022    17
# 19       reg    chuck  NYJ    2022    17
# 20       reg    chuck  PHI    2022    17
# 21       reg    chuck  JAX    2022    17
# 22       reg    chuck  DEN    2022    17
# 23       reg    chuck  CAR    2022    17
# 24        ud    chuck  DEN    2022    17
# 26       mnf    chuck  CIN    2022    17
# 27        bb  griffin  JAX    2022    17
# 28       reg  griffin   NE    2022    17
# 29       reg  griffin  BAL    2022    17
# 30       reg  griffin   LA    2022    17
# 31       reg  griffin  ARI    2022    17
# 32       reg  griffin  WAS    2022    17
# 33        ud  griffin  ARI    2022    17
# 35       mnf  griffin  BUF    2022    17
# 36        bb    harry  MIN    2022    17
# 37       reg    harry   SF    2022    17
# 38       reg    harry  NYJ    2022    17
# 39       reg    harry  MIA    2022    17
# 40       reg    harry  CAR    2022    17
# 41       reg    harry  ATL    2022    17
# 42        ud    harry  DEN    2022    17
# 44       mnf    harry  CIN    2022    17
# 45        bb   hunter  NYG    2022    17
# 46       reg   hunter  JAX    2022    17
# 47       reg   hunter  NYJ    2022    17
# 48       reg   hunter  PIT    2022    17
# 49       reg   hunter  CLE    2022    17
# 50       reg   hunter  CIN    2022    17
# 51        ud   hunter   LV    2022    17
# 53       mnf   hunter  CIN    2022    17

# %%
[team for team in transformed['pick'].unique() if team not in teams]
# Out:
# []

# %% [markdown]
# spreads are indicative of the away team

# %%
joined = pd.merge(transformed, nfl.import_schedules([season])[['game_id', 'season', 'week', 'away_team', 'home_team', 'away_score', 'home_score', 'result', 'spread_line']], on=['season', 'week'])

reduced = joined[(joined['pick'] == joined['away_team']) | (joined['pick'] == joined['home_team'])]
del joined
print(len(reduced), len(transformed))


reduced['away_cover'] = reduced.apply(utils.cover_result, axis=1)
reduced['home_cover'] = 1 - reduced['away_cover']

reduced['pick_result'] = reduced.apply(utils.pick_result, axis=1)
reduced
# Out:
# 41 48
#     pick_type   picker pick  season  week          game_id away_team  \
# 3          bb    final  JAX    2022    17  2022_17_JAX_HOU       JAX
# 29        reg    final  PIT    2022    17  2022_17_PIT_BAL       PIT
# 42        reg    final  MIN    2022    17   2022_17_MIN_GB       MIN
# 56        reg    final  NYJ    2022    17  2022_17_NYJ_SEA       NYJ
# 66        reg    final  NYG    2022    17  2022_17_IND_NYG       IND
# 85        reg    final   SF    2022    17    2022_17_SF_LV        SF
# 91         ud    final  ARI    2022    17  2022_17_ARI_ATL       ARI
# 133        bb      ben  LAC    2022    17   2022_17_LA_LAC        LA
# 139       reg      ben   KC    2022    17   2022_17_DEN_KC       DEN
# 155       reg      ben   NE    2022    17   2022_17_MIA_NE       MIA
# 173       reg      ben  CAR    2022    17   2022_17_CAR_TB       CAR
# 189       reg      ben  CLE    2022    17  2022_17_CLE_WAS       CLE
# 201       reg      ben  IND    2022    17  2022_17_IND_NYG       IND
# 211        ud      ben  ARI    2022    17  2022_17_ARI_ATL       ARI
# 252        bb    chuck  MIN    2022    17   2022_17_MIN_GB       MIN
# 266       reg    chuck  NYJ    2022    17  2022_17_NYJ_SEA       NYJ
# 277       reg    chuck  PHI    2022    17   2022_17_NO_PHI        NO
# 288       reg    chuck  JAX    2022    17  2022_17_JAX_HOU       JAX
# 304       reg    chuck  DEN    2022    17   2022_17_DEN_KC       DEN
# 323       reg    chuck  CAR    2022    17   2022_17_CAR_TB       CAR
# 334        ud    chuck  DEN    2022    17   2022_17_DEN_KC       DEN
# 363        bb  griffin  JAX    2022    17  2022_17_JAX_HOU       JAX
# 380       reg  griffin   NE    2022    17   2022_17_MIA_NE       MIA
# 404       reg  griffin  BAL    2022    17  2022_17_PIT_BAL       PIT
# 418       reg  griffin   LA    2022    17   2022_17_LA_LAC        LA
# 421       reg  griffin  ARI    2022    17  2022_17_ARI_ATL       ARI
# 444       reg  griffin  WAS    2022    17  2022_17_CLE_WAS       CLE
# 451        ud  griffin  ARI    2022    17  2022_17_ARI_ATL       ARI
# 492        bb    harry  MIN    2022    17   2022_17_MIN_GB       MIN
# 505       reg    harry   SF    2022    17    2022_17_SF_LV        SF
# 521       reg    harry  NYJ    2022    17  2022_17_NYJ_SEA       NYJ
# 530       reg    harry  MIA    2022    17   2022_17_MIA_NE       MIA
# 548       reg    harry  CAR    2022    17   2022_17_CAR_TB       CAR
# 556       reg    harry  ATL    2022    17  2022_17_ARI_ATL       ARI
# 574        ud    harry  DEN    2022    17   2022_17_DEN_KC       DEN
# 606        bb   hunter  NYG    2022    17  2022_17_IND_NYG       IND
# 618       reg   hunter  JAX    2022    17  2022_17_JAX_HOU       JAX
# 641       reg   hunter  NYJ    2022    17  2022_17_NYJ_SEA       NYJ
# 659       reg   hunter  PIT    2022    17  2022_17_PIT_BAL       PIT
# 669       reg   hunter  CLE    2022    17  2022_17_CLE_WAS       CLE
# 700        ud   hunter   LV    2022    17    2022_17_SF_LV        SF
#
#     home_team  away_score  home_score  result  spread_line  away_cover  \
# 3         HOU        31.0         3.0   -28.0         -3.5           1
# 29        BAL        16.0        13.0    -3.0          1.0           1
# 42         GB        17.0        41.0    24.0          3.0           0
# 56        SEA         6.0        23.0    17.0         -1.0           0
# 66        NYG        10.0        38.0    28.0          5.5           0
# 85         LV        37.0        34.0    -3.0        -10.0           0
# 91        ATL        19.0        20.0     1.0          7.0           1
# 133       LAC        10.0        31.0    21.0          6.5           0
# 139        KC        24.0        27.0     3.0         13.5           1
# 155        NE        21.0        23.0     2.0          3.0           1
# 173        TB        24.0        30.0     6.0          3.5           0
# 189       WAS        24.0        10.0   -14.0          1.0           1
# 201       NYG        10.0        38.0    28.0          5.5           0
# 211       ATL        19.0        20.0     1.0          7.0           1
# 252        GB        17.0        41.0    24.0          3.0           0
# 266       SEA         6.0        23.0    17.0         -1.0           0
# 277       PHI        20.0        10.0   -10.0          5.5           1
# 288       HOU        31.0         3.0   -28.0         -3.5           1
# 304        KC        24.0        27.0     3.0         13.5           1
# 323        TB        24.0        30.0     6.0          3.5           0
# 334        KC        24.0        27.0     3.0         13.5           1
# 363       HOU        31.0         3.0   -28.0         -3.5           1
# 380        NE        21.0        23.0     2.0          3.0           1
# 404       BAL        16.0        13.0    -3.0          1.0           1
# 418       LAC        10.0        31.0    21.0          6.5           0
# 421       ATL        19.0        20.0     1.0          7.0           1
# 444       WAS        24.0        10.0   -14.0          1.0           1
# 451       ATL        19.0        20.0     1.0          7.0           1
# 492        GB        17.0        41.0    24.0          3.0           0
# 505        LV        37.0        34.0    -3.0        -10.0           0
# 521       SEA         6.0        23.0    17.0         -1.0           0
# 530        NE        21.0        23.0     2.0          3.0           1
# 548        TB        24.0        30.0     6.0          3.5           0
# 556       ATL        19.0        20.0     1.0          7.0           1
# 574        KC        24.0        27.0     3.0         13.5           1
# 606       NYG        10.0        38.0    28.0          5.5           0
# 618       HOU        31.0         3.0   -28.0         -3.5           1
# 641       SEA         6.0        23.0    17.0         -1.0           0
# 659       BAL        16.0        13.0    -3.0          1.0           1
# 669       WAS        24.0        10.0   -14.0          1.0           1
# 700        LV        37.0        34.0    -3.0        -10.0           0
#
#      home_cover  pick_result
# 3             0            2
# 29            0            1
# 42            1            0
# 56            1            0
# 66            1            1
# 85            1            0
# 91            0            0
# 133           1            2
# 139           0            0
# 155           0            0
# 173           1            0
# 189           0            1
# 201           1            0
# 211           0            0
# 252           1            0
# 266           1            0
# 277           0            0
# 288           0            1
# 304           0            1
# 323           1            0
# 334           0            0
# 363           0            2
# 380           0            0
# 404           0            0
# 418           1            0
# 421           0            1
# 444           0            0
# 451           0            0
# 492           1            0
# 505           1            0
# 521           1            0
# 530           0            1
# 548           1            0
# 556           0            0
# 574           0            0
# 606           1            2
# 618           0            1
# 641           1            0
# 659           0            1
# 669           0            1
# 700           1            0

# %%
reduced.picker.value_counts()
# Out:
# final      7
# ben        7
# chuck      7
# griffin    7
# harry      7
# hunter     6
# Name: picker, dtype: int64
